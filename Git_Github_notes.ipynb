# %% [markdown]
# **Version Control System:**
#
# **How do you collaborate with team members?**
#
# **Categorize into 3 Parts:**
# 1. Local version control:
#     - Local copy.
#
# 	**Q. what if i want to collaborate with system.**
#
# 	**Q. what if machine/system failure?**
# 2. CVCS: centralized version control system.
#
# 	**what if centralized system failure even if multiple team can work?**
# 3. DVCS: Distributed Version Control System: Ex: git -->Remote Repositories (GitHib, GitLab, Bitbucket..).
#
# **History of Git:**
# - Open source projects:
#   - Anyone can contribute to project and riase PR(Pull Request)--> Reviewer should accept.
#   - They can get contribution from the world.
#
# **git: 2005**
#
# **Advantages:**
# - Simple.
# - Fast.
# - Branching.
# - Fully Distributed.
#
# **Project can be Open Source or Propritery.**
#
# **Install git:**
# - download and install
# https://git-scm.com/install/windows
#
# **default get master branch: can be renamed main.**
#
# **while installing: Default behavior of git pull?**
#
# **default fast-forward or merge):**
# - Fast-forward the current branch to the fetched branch when possible, otherwise create a merge commit.
#
# **Rebase:**
# - Rebase the current branch onto the fetched branch. if ther are no local commits to rebase, this is equivalent to a fast-forward.
#
# **Only Ever fast-forward:**
# - Fast-forward to the fetched branch. Fail if that is not possible.
#
#
# go to command line: cmd or powershell or gitbash or any terminal.
# git --version
#
# --default editor can keep like notepad++ or vim or ...
#
# commands:
# git config --global --list
#
# git config --global user.name "vardhan"
# git config --global user.email "vardha@email.com"
#
# git config --global user.name
# git config --global user.email
#
# git config --global --list
#
# Q. what is working directory?
# Q. what is staging area?
# Q. what is commit history?
#
#
# git --version
# git status     --give error if not git, fatal: not a git repository (or any of the parent directories): .git
# git init   --> empty git repo will create--initiate this when no git repository.--here by default master branch will create.
# git init -b main --if want to create init with main branch.
# Initialized empty Git repository in D:/desktop_repo/naven_git/.git/
#
# git status
# On branch main
# nothing to commit, working tree clean
#
# D:/desktop_repo/naven_git/.git/   --if delete this .git hidden file, everything will be lost.
# -- .git will track everything.
#
# git add filename
# --if you want to unstage any file:
# git rm --cached Firstcode.txt
#
#
# git commit -m "this is first commit"    --git change checksum for every commit.--checksum 863442e
# [main (root-commit) 863442e] This is first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 Firstcode.txt
#
# git log
# commit 863442ea57214fc672897587bcc4dfac55997677 (HEAD -> main)
# Author: vennapusavijay <vennapusa.vijay@gmail.com>
# Date:   Sat Nov 29 20:43:50 2025 +0530
#
#     This is first commit

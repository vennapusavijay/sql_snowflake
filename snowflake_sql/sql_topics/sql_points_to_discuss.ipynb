# %% [markdown]
# **SQL Coding rules:**
#
#         1. Few lines of Code.
#         2. Code with Performance.
#         3. Code with a Style.
#
# **Note: For good code review.**
#
# **Rules:**
#
# - Add new lines for each keyword: add Tab before column in SELECT.
# - Upper Case all keywords.
# - Add write spaces.
#
# **SELECT:**
#
# - Q. how do you retrieve/fetch data from table?
# - Q. How to select all columns?
# - Q. what is * ?
# - Q. How to select required Columns?
# - Q. Default which order column will displayed?
# - Q. Can we change default order of columns in select statement?
#
# **DISTINCT:**
#
# - Q. is default SELECT statement will remove duplicate from result set?
# - Q. what is distinct keyword?
# - Q. Can distinct apply to multiple columns?
# - Q. can UNIQUE will work same as DISTINCT?
# - Q. how can you remove duplicates?
#
# **Alias:**
#
# - Q. what is alias?
# - Q. When we use column level and table aliases?
# - Q. is aliases will store in database tables?
#
# **WHERE:**
#
# - Q.why we use where clause/How do we filter data?
# - Q.how to apply condition in where clause to get required data?
#
# **Requirement Questions:**
#
# - Q. Retrieve all employeess whose sal is greater than 2000?
#
#                       **Operators:**
#
# **BETWEEN:**
#
# - Q. is boundaries included in condition?
# - Q. which is better AND and BETWEEN?
#
# **IN/NOT IN:**
#
# - Q. how we can handle nulls if nulls avaialble?
#
# **LIKE:**
#
# - Q.Retrieve all employees whose name starts with S?
# - Q.Retrieve all employees whose name ends with K?
# - Q.Retrieve all employees whose name contains A?
# - Q.Retrieve all employees whose name contians second letter P?
#
# **ORDER BY:**
#
# - Q. is default SELECT Statement will order by result?
# - Q. what is default order?
# - Q. how to order based on multiple columns?
# - Q. Can we use columns order number/position of column in order by clause?
# - Q. Can we use derived/calculated columns in order by clause?
# - Q. how null records can handled in order by clause?
# - Q. when we use nulls first or nulls last keywords?
#
# **Joins:**
#
#             **Show data in excel ans explain.**
#
# - Q.What is join key?
# - Q.is mandatory have relationship parent and child to join tables?
# - Q.What is driving table?
# - Q.Can we join morethen 2 tables?
# - Q.What is column ambiguity?
#
# **Set Operators:**
#
# - Q. what is difference between joins and set operators?
